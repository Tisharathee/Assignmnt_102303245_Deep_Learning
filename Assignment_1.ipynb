# %%
import numpy as np
from sklearn.metrics import accuracy_score

# %%
class MyPerceptron:

  def __init__(self, lr=0.1, epochs=10):
        self.lr = lr
        self.epochs = epochs
        self.weights = None
        self.bias = None


  def step_activ_func(self, activation):
        if activation >= 0:
            return 1
        else:
            return 0
  def fit(self, X, Y):
        n_samples, n_features = X.shape
        self.weights = np.zeros(n_features)
        self.bias = 0

        for _ in range(self.epochs):
            for i in range(n_samples):

                linear_output = np.dot(X[i], self.weights) + self.bias
                y_predicted = self.step_activ_func(linear_output)

                update = self.lr * (Y[i] - y_predicted)

                self.weights += update * X[i]
                self.bias += update
  def predict(self, X):
        y_predicted = []
        for i in range(len(X)):
            linear_output = np.dot(X[i], self.weights) + self.bias
            y_predicted.append(self.step_activ_func(linear_output))
        return np.array(y_predicted)

# %%
print("AND Gate")

X = np.array([
    [0,0],
    [0,1],
    [1,0],
    [1,1]
])

Y = np.array([0,0,0,1])

clf = MyPerceptron()
clf.fit(X,Y)

Y_pred = clf.predict(X)

print("Predicted:",Y_pred)
print("Accuracy:",accuracy_score(Y,Y_pred))
# Out:
# AND Gate
# Predicted: [0 0 0 1]
# Accuracy: 1.0

# %%
print("\nOR Gate")

Y = np.array([0,1,1,1])

clf = MyPerceptron()
clf.fit(X,Y)

Y_pred = clf.predict(X)

print("Predicted:",Y_pred)
print("Accuracy:",accuracy_score(Y,Y_pred))
# Out:
# OR Gate
# Predicted: [0 1 1 1]
# Accuracy: 1.0

# %%
print("\nNAND Gate")

Y = np.array([1,1,1,0])

clf = MyPerceptron()
clf.fit(X,Y)

Y_pred = clf.predict(X)

print("Predicted:",Y_pred)
print("Accuracy:",accuracy_score(Y,Y_pred))
# Out:
# NAND Gate
# Predicted: [1 1 1 0]
# Accuracy: 1.0

# %%
print("\nNOR Gate")

Y = np.array([1,0,0,0])

clf = MyPerceptron()
clf.fit(X,Y)

Y_pred = clf.predict(X)

print("Predicted:",Y_pred)
print("Accuracy:",accuracy_score(Y,Y_pred))
# Out:
# NOR Gate
# Predicted: [1 0 0 0]
# Accuracy: 1.0
